# %% [markdown]
# <a href="https://colab.research.google.com/github/bdugick89/Data-Science-Bootcamp/blob/main/8e_Pandas_Unpivot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# From https://stackoverflow.com/a/48136002

# %%
import pandas as pd
import markdown

# %%
# Assign Markdown string to a variable
table_md = '''|Date|A|B|C|D|E |
|----|-|-|-|-|--|
|2005|1|2|3|4|50|
|2006|6|7|8|9|10|'''
table_md
# Out:
# '|Date|A|B|C|D|E |\n|----|-|-|-|-|--|\n|2005|1|2|3|4|50|\n|2006|6|7|8|9|10|'

# %%
# Convert Markdown to HTML to a DataFrame
table_html=markdown.markdown(table_md, extensions=['markdown.extensions.tables'])
table_html

df = pd.read_html(table_html)[0]
df
# Out:
#    Date  A  B  C  D   E
# 0  2005  1  2  3  4  50
# 1  2006  6  7  8  9  10

# %% [markdown]
# # Using .stack()

# %%
df.set_index('Date')
# Out:
#       A  B  C  D   E
# Date
# 2005  1  2  3  4  50
# 2006  6  7  8  9  10

# %%
df.set_index('Date').stack()
# Out:
# Date
# 2005  A     1
#       B     2
#       C     3
#       D     4
#       E    50
# 2006  A     6
#       B     7
#       C     8
#       D     9
#       E    10
# dtype: int64

# %%
df.set_index('Date').stack().reset_index(name='Val')
# Out:
#    Date level_1  Val
# 0  2005       A    1
# 1  2005       B    2
# 2  2005       C    3
# 3  2005       D    4
# 4  2005       E   50
# 5  2006       A    6
# 6  2006       B    7
# 7  2006       C    8
# 8  2006       D    9
# 9  2006       E   10

# %%
df_stack = df.set_index('Date').stack().reset_index(name='Val').rename(columns={'level_1':'X'})
df_stack
# Out:
#    Date  X  Val
# 0  2005  A    1
# 1  2005  B    2
# 2  2005  C    3
# 3  2005  D    4
# 4  2005  E   50
# 5  2006  A    6
# 6  2006  B    7
# 7  2006  C    8
# 8  2006  D    9
# 9  2006  E   10

# %% [markdown]
# # Using .melt()

# %% [markdown]
# ## Sorted by "X", then "Date"

# %%
df_melt = df.melt('Date', var_name='X', value_name='Val')
df_melt
# Out:
#    Date  X  Val
# 0  2005  A    1
# 1  2006  A    6
# 2  2005  B    2
# 3  2006  B    7
# 4  2005  C    3
# 5  2006  C    8
# 6  2005  D    4
# 7  2006  D    9
# 8  2005  E   50
# 9  2006  E   10

# %% [markdown]
# ## Sorted by "Date", then "X"

# %%
df_melt2 = ( df
            .melt('Date', var_name='X', value_name='Val')
            .sort_values(['Date','X'])
            .reset_index(drop=True)
)
df_melt2
